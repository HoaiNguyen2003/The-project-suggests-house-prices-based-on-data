# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep
import pandas as pd

# %%
from selenium import webdriver

# Khởi tạo trình duyệt Chrome
driver = webdriver.Chrome()

# Truy cập trang web
driver.get("https://i-batdongsan.com/can-ban-nha-mat-tien.htm")

# %%
# lấy link các page từ trang 1 đến trang 1000
link_page = []
for i in range(1,271):
    link_page.append('https://i-batdongsan.com/can-ban-nha-dat/p' + str(i) +'.htm')

# %%
link_page
# Out:
# ['https://i-batdongsan.com/can-ban-nha-dat/p1.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p2.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p3.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p4.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p5.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p6.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p7.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p8.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p9.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p10.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p11.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p12.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p13.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p14.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p15.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p16.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p17.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p18.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p19.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p20.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p21.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p22.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p23.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p24.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p25.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p26.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p27.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p28.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p29.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p30.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p31.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p32.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p33.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p34.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p35.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p36.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p37.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p38.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p39.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p40.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p41.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p42.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p43.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p44.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p45.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p46.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p47.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p48.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p49.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p50.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p51.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p52.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p53.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p54.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p55.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p56.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p57.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p58.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p59.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p60.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p61.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p62.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p63.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p64.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p65.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p66.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p67.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p68.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p69.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p70.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p71.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p72.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p73.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p74.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p75.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p76.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p77.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p78.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p79.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p80.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p81.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p82.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p83.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p84.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p85.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p86.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p87.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p88.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p89.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p90.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p91.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p92.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p93.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p94.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p95.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p96.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p97.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p98.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p99.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p100.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p101.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p102.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p103.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p104.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p105.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p106.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p107.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p108.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p109.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p110.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p111.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p112.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p113.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p114.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p115.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p116.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p117.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p118.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p119.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p120.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p121.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p122.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p123.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p124.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p125.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p126.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p127.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p128.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p129.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p130.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p131.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p132.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p133.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p134.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p135.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p136.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p137.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p138.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p139.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p140.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p141.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p142.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p143.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p144.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p145.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p146.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p147.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p148.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p149.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p150.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p151.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p152.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p153.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p154.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p155.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p156.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p157.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p158.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p159.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p160.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p161.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p162.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p163.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p164.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p165.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p166.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p167.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p168.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p169.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p170.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p171.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p172.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p173.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p174.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p175.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p176.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p177.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p178.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p179.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p180.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p181.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p182.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p183.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p184.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p185.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p186.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p187.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p188.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p189.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p190.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p191.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p192.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p193.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p194.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p195.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p196.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p197.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p198.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p199.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p200.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p201.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p202.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p203.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p204.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p205.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p206.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p207.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p208.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p209.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p210.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p211.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p212.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p213.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p214.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p215.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p216.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p217.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p218.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p219.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p220.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p221.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p222.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p223.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p224.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p225.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p226.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p227.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p228.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p229.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p230.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p231.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p232.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p233.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p234.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p235.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p236.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p237.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p238.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p239.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p240.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p241.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p242.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p243.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p244.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p245.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p246.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p247.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p248.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p249.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p250.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p251.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p252.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p253.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p254.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p255.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p256.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p257.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p258.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p259.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p260.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p261.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p262.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p263.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p264.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p265.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p266.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p267.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p268.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p269.htm',
#  'https://i-batdongsan.com/can-ban-nha-dat/p270.htm']

# %%
# truy cập vào từng page và lấy link các bài đăng
link_post = []
for i in link_page:
    driver.get(i)
    sleep(1.5)
    link = driver.find_elements(By.XPATH,'//*[@class="ct_title"]/a')
    for j in link:
        link_post.append(j.get_attribute('href'))
        # viết link vào file txt theo dạng danh sách vào F:\Thống Kê Máy Tính\Crawl_Data\file_txt\link_post.txt
        with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\link_post1.txt','w') as f:
            for item in link_post:
                f.write("%s\n" % item)

# %%
# dùng bs4 để lấy thông tin từng bài đăng
from bs4 import BeautifulSoup
import requests
import re
from tqdm.notebook import tqdm

list_dia_chi= []
list_price = []
list_infor = []
list_ten_LH = []
list_sdt_LH = []
# lấy thông tin từng bài đăng thông qua link đã lấy được
# truy cập vào từng link nếu link nào bị lỗi thì bỏ qua link đó, đọc file txt để lấy link
with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\link_post1.txt', 'r') as f:
    link_post = f.read().splitlines()
for i in tqdm(link_post):
    try:
        response = requests.get(i)
        soup = BeautifulSoup(response.text, 'html.parser')

        # lấy giá
        price = soup.find('td', class_ = 'price').text.strip()
        list_price.append(price)

        # viết giá vào file txt theo dạng danh sách
        with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\list_price1.txt', 'w', encoding='utf-8') as file:
            for chuoi in list_price:
                file.write(chuoi + '\n')

        # lấy địa chỉ
        dia_chi = soup.find('span', class_ = 'value').text
        list_dia_chi.append(dia_chi)

        # viết địa chỉ vào file txt theo dạng danh sách
        with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\list_dia_chi1.txt', 'w', encoding='utf-8') as file:
            for chuoi in list_dia_chi:
                file.write(chuoi + '\n')

        # lấy thông tin liên hệ
        LH = soup.find('div', class_ = 'name').text.strip()
        list_ten_LH.append(LH)

        # # viết thông tin liên hệ vào file txt theo dạng danh sách
        with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\list_ten_LH1.txt', 'w', encoding='utf-8') as file:
            for chuoi in list_ten_LH:
                file.write(chuoi + '\n')

        # lấy số điện thoại liên hệ
        sdt_LH = soup.find('div', class_ = 'fone').text.strip()
        list_sdt_LH.append(sdt_LH)

        # # viết số điện thoại liên hệ vào file txt theo dạng danh sách
        with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\list_sdt_LH1.txt', 'w', encoding='utf-8') as file:
            for chuoi in list_sdt_LH:
                file.write(chuoi + '\n')

        # lấy thông tin chi tiết
        infor = soup.find('div', class_ = 'infor')
        # tách thông tin chi tiết thành từng phần vì có nhiều 'tr' trong 'div' infor
        infor = infor.find_all('td')
        # lấy thông tin chi tiết
        infor = [i.text.strip() for i in infor]
        list_infor.append(infor)

        # # viết thông tin chi tiết vào file txt theo dạng danh sách
        with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\list_infor1.txt', 'w', encoding='utf-8') as file:
            for sublist in list_infor:
                # Sử dụng join để nối các phần tử trong sublist thành một chuỗi và ghi vào tệp
                line = '\t'.join(sublist)  # Sử dụng ký tự tab để phân tách các phần tử trong sublist
                file.write(line + '\n')
    except:
        pass
# Out:
#   0%|          | 0/5400 [00:00<?, ?it/s]

# %%
print(len(list_price))
print(len(list_ten_LH))
print(len(list_sdt_LH))
print(len(list_infor))
print(len(list_dia_chi))
# Out:
# 5400
# 5400
# 5400
# 5400
# 5400

# %%
# đọc file txt để lấy thông tin
with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\list_price1.txt', 'r', encoding='utf-8') as f:
    list_price = f.read().splitlines()
with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\list_ten_LH1.txt', 'r', encoding='utf-8') as f:
    list_ten_LH = f.read().splitlines()
with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\list_sdt_LH1.txt', 'r', encoding='utf-8') as f:
    list_sdt_LH = f.read().splitlines()
with open('F:\Thống Kê Máy Tính\Crawl_Data/file_txt\list_infor1.txt', 'r', encoding='utf-8') as f:
    list_infor = f.read().splitlines()

# %%
len(list_price)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# f:\Thống Kê Máy Tính\Crawl_Data\Crawl_data_bds.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/f%3A/Th%E1%BB%91ng%20K%C3%AA%20M%C3%A1y%20T%C3%ADnh/Crawl_Data/Crawl_data_bds.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> len(list_price)
#
# NameError: name 'list_price' is not defined
